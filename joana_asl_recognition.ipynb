# %% [markdown]
# <a href="https://colab.research.google.com/github/JoanaJin/final_project_ironhack_09.23/blob/main/joana_asl_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install mediapipe

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import shutil
import time
import json



def vidToFrame(vid_file,out_dir):


    video_capture = cv2.VideoCapture(vid_file)

    output_folder = out_dir
    #shutil.rmtree(output_folder)
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Initialize frame count and flag
    vid_cnt = 0
    success = True



    # Read the next frame
    #success, frame = video_capture.read()


    frame_count=0
    while frame_count < 48:

        frame_count += 1
        success, frame = video_capture.read()
        frame_path = os.path.join(output_folder, f"frame_{frame_count}.jpg")

        if frame is not None:
            cv2.imwrite(frame_path, frame)


#        cv2.imshow('frame', frame)

        if cv2.waitKey(20) & 0xFF == ord('q') :
            break

    # Release the video capture object
    video_capture.release()
    cv2.destroyAllWindows()





file_path = '/content/drive/MyDrive/final_project/wlasl_data/WLASL_v0.3.json'
missing_file_path = '/content/drive/MyDrive/final_project/wlasl_data/missing.txt'
videos_dir = '/content/drive/MyDrive/final_project/wlasl_data/videos/'

# Load the WLASL dataset
with open(file_path) as file:
    wlasl = json.load(file)

# Read the missing video IDs from the file
with open(missing_file_path, 'r') as file:
    missing_videos = file.read().splitlines()

# Specify the base directory for the dataset
dataset_dir = '/content/drive/MyDrive/final_project/working/Dataset/frames'

# Create necessary directories
os.makedirs(dataset_dir, exist_ok=True)
os.makedirs(os.path.join(dataset_dir, 'Train'), exist_ok=True)
os.makedirs(os.path.join(dataset_dir, 'Test'), exist_ok=True)

# Process each class in the WLASL dataset
for class_data in wlasl:
    class_name = class_data['gloss']
    print(class_name)

    for instance in class_data['instances']:
        video_id = instance['video_id']

        if video_id not in missing_videos:
            video_file = os.path.join(videos_dir, video_id + '.mp4')

            if instance['split'] == 'train':
                train_dir = os.path.join(dataset_dir, 'Train', class_name, video_id)
                os.makedirs(train_dir, exist_ok=True)
                vidToFrame(video_file, train_dir)
                print('train', video_id)
            else:
                test_dir = os.path.join(dataset_dir, 'Test', class_name, video_id)
                os.makedirs(test_dir, exist_ok=True)
                vidToFrame(video_file, test_dir)
                print('test', video_id)
# Out:
# Streaming output truncated to the last 5000 lines.
# train 22455
# train 22456
# test 22457
# train 22459
# train 22462
# flood
# train 22489
# train 22481
# test 22483
# train 22485
# fork
# test 65762
# test 23005
# train 23006
# train 23009
# four
# train 69333
# train 65768
# train 23199
# test 23200
# train 23202
# fun
# train 69338
# train 23859
# train 65793
# test 23851
# test 23852
# train 23853
# train 23857
# funeral
# train 23840
# train 23841
# train 23842
# test 23844
# train 23847
# furniture
# train 23907
# test 23913
# train 23902
# gallaudet
# train 65799
# train 23987
# test 23990
# train 23993
# general
# train 24249
# train 24258
# train 24259
# train 24250
# test 24251
# train 24253
# ghost
# train 65815
# train 24515
# train 24516
# test 24518
# train 24519
# train 24522
# give up
# train 65820
# train 24680
# train 24681
# test 24682
# train 24685
# train 24687
# glass
# train 69344
# train 65821
# train 24741
# train 24734
# train 24746
# test 24735
# train 24736
# gorilla
# train 25174
# train 65838
# test 25167
# test 25168
# test 25171
# gray
# train 25578
# train 65852
# test 25570
# test 25572
# train 25573
# train 25576
# guide
# train 25941
# train 25942
# test 25945
# train 25946
# train 25948
# habit
# train 26082
# train 26083
# test 26086
# train 26089
# health
# train 26914
# train 26915
# test 26916
# test 26917
# test 26919
# train 26921
# hearing aid
# train 65885
# train 26959
# test 26960
# train 26962
# train 26965
# heaven
# train 65887
# test 27087
# test 27078
# train 27079
# train 27082
# heavy
# train 27095
# train 27096
# train 27097
# test 27099
# train 27102
# helmet
# train 27186
# train 27187
# test 27188
# train 27190
# train 27192
# hide
# train 27375
# train 27376
# train 27377
# test 27379
# train 27382
# high school
# train 27436
# train 27434
# train 27439
# train 27441
# hockey
# train 65895
# train 27633
# train 27634
# test 27635
# train 27637
# hold
# train 27662
# train 27665
# train 27666
# test 27659
# train 27661
# honest
# train 27823
# train 27824
# test 27826
# train 27827
# train 27829
# hug
# train 65909
# train 28260
# train 28261
# test 28263
# train 28267
# hunt
# train 28397
# train 65912
# test 28389
# test 28394
# train 28395
# image
# train 28886
# train 28876
# test 28877
# test 28878
# train 28881
# influence
# train 65939
# train 29614
# train 29615
# train 29616
# train 29619
# train 29621
# interesting
# train 30169
# test 30170
# test 30171
# train 30172
# test 30173
# train 30175
# interpreter
# train 65954
# train 30257
# test 30258
# train 30260
# train 30262
# iran
# train 30559
# train 30560
# train 30561
# train 30562
# test 30563
# train 30565
# test 30566
# italy
# train 30748
# train 65969
# train 30755
# test 30745
# train 30746
# jewish
# train 65979
# train 31093
# test 31094
# test 31095
# train 31096
# judge
# train 31260
# test 31261
# train 31264
# test 31252
# train 31253
# key
# train 65989
# train 31572
# test 31564
# test 31565
# train 31566
# train 31569
# label
# train 31984
# train 66006
# train 31976
# test 31978
# test 31979
# test 31981
# leaf
# train 69384
# train 66021
# train 32554
# test 32555
# train 32557
# train 32559
# left
# train 32725
# train 32728
# test 32729
# test 32735
# train 32722
# lend
# train 66034
# train 32824
# train 32825
# test 32827
# train 32828
# train 32830
# less
# train 69386
# train 32877
# train 32878
# test 32881
# train 32884
# linguistics
# train 66073
# train 33374
# train 33375
# test 33376
# test 33377
# test 33379
# train 33380
# lonely
# train 66081
# train 33766
# test 33767
# test 33768
# test 33770
# train 33771
# long
# train 33804
# train 33805
# train 33806
# test 33808
# train 33812
# magic
# train 66092
# train 34397
# test 34398
# train 34400
# train 34402
# mainstream
# train 34510
# train 34511
# test 34512
# train 34514
# train 34516
# major
# train 34543
# train 34544
# train 34545
# test 34547
# train 34550
# manager
# train 34699
# test 34701
# test 34702
# train 34703
# train 34705
# maximum
# train 35209
# train 35210
# train 35211
# test 35212
# train 35214
# train 35216
# me
# train 35544
# train 35545
# test 35546
# train 35548
# mexico
# train 35885
# train 66119
# train 35890
# train 35893
# test 35881
# train 35884
# middle
# train 35974
# train 66122
# train 35965
# test 35966
# test 35968
# train 35969
# train 35972
# mind
# train 66123
# train 36118
# train 36119
# test 36121
# train 36124
# misunderstand
# train 36422
# train 36414
# test 36416
# train 36419
# monster
# train 36713
# train 36714
# train 36715
# test 36717
# train 36720
# multiply
# train 37278
# test 37267
# test 37268
# train 37269
# test 37270
# train 37273
# myself
# train 37483
# train 37484
# train 37485
# train 37488
# test 37489
# train 37490
# nothing
# train 38849
# train 66192
# train 38830
# test 38841
# train 38842
# train 38844
# october
# train 39360
# train 39361
# train 39362
# test 39364
# train 39368
# odd
# train 39378
# train 39379
# test 39382
# train 39385
# offer
# train 39425
# train 39426
# train 39427
# test 39428
# train 39430
# train 39432
# on
# train 69420
# train 39839
# test 39840
# test 39841
# train 39845
# only
# train 39874
# train 39875
# test 39877
# test 39878
# train 39879
# train 39881
# opposite
# train 40050
# train 40051
# test 40052
# train 40054
# train 40056
# out
# train 40403
# test 40409
# train 40397
# test 40398
# train 40399
# overlook
# train 66253
# train 40577
# train 40578
# test 40579
# train 40581
# path
# train 41480
# train 41481
# train 41482
# test 41483
# train 41485
# train 41487
# percent
# train 41976
# train 41977
# test 41979
# train 41982
# physics
# train 42552
# train 42553
# train 42554
# test 42555
# train 42557
# train 42560
# piano
# train 42565
# train 42566
# test 42567
# train 42569
# train 42571
# pick
# train 66291
# train 42585
# test 42597
# test 42588
# train 42589
# pie
# train 42671
# train 42672
# test 42673
# train 42675
# train 42677
# plate
# train 66299
# test 43113
# test 43124
# train 43114
# test 43117
# pocket
# train 43380
# train 43381
# train 43382
# test 43384
# train 43385
# train 43388
# popcorn
# train 43697
# train 43698
# test 43700
# train 43703
# positive
# train 66313
# train 43809
# test 43810
# train 43812
# train 43814
# pregnant
# train 44242
# train 44233
# test 44234
# test 44235
# test 44237
# prevent
# train 44441
# train 44442
# train 44443
# test 44445
# train 44448
# proof
# train 66341
# train 44949
# train 44950
# train 44951
# test 44953
# train 44956
# pumpkin
# train 66352
# train 45324
# train 45325
# test 45327
# train 45330
# purpose
# train 45448
# train 45449
# train 45450
# test 45451
# train 45453
# train 45455
# race
# train 45864
# train 45865
# train 45866
# train 45867
# test 45870
# train 45873
# realize
# train 46336
# test 46327
# test 46330
# test 46333
# recognize
# train 46588
# train 46589
# train 46590
# test 46592
# train 46596
# refuse
# train 66381
# train 46863
# train 46864
# test 46865
# train 46867
# train 46870
# relationship
# train 66384
# train 47038
# test 47039
# test 47040
# test 47042
# repeat
# train 47300
# train 47301
# train 47302
# train 47305
# train 47307
# replace
# train 66392
# train 47332
# test 47333
# train 47335
# train 47337
# report
# train 47357
# train 47358
# train 47362
# represent
# train 47380
# train 47381
# train 47382
# test 47383
# test 47384
# train 47385
# train 47387
# request
# train 47450
# train 47451
# test 47453
# train 47457
# responsibility
# train 66397
# test 47640
# test 47641
# train 47642
# test 47643
# train 47644
# result
# train 47738
# train 66399
# train 47731
# test 47732
# test 47733
# train 47734
# train 47736
# reveal
# train 47846
# train 47847
# test 47851
# train 47840
# test 47841
# ring
# train 48159
# train 48163
# train 48166
# test 48175
# train 48160
# rob
# train 48334
# train 48325
# train 48336
# test 48327
# test 48328
# train 48329
# test 48330
# train 48331
# rock
# train 48378
# train 66411
# train 48371
# test 48373
# test 48374
# test 48376
# role
# train 48404
# train 48405
# test 48406
# train 48408
# train 48411
# rope
# train 48557
# train 48558
# test 48560
# train 48563
# rush
# train 48890
# train 48891
# test 48893
# test 48894
# train 48897
# salute
# train 49149
# train 49150
# test 49152
# train 49156
# satisfy
# train 66427
# train 49318
# train 49319
# test 49320
# train 49324
# search
# train 49931
# train 49941
# train 49933
# train 49934
# test 49936
# selfish
# train 50244
# train 50245
# train 50246
# train 50249
# train 50252
# sensitive
# train 66447
# train 50398
# train 50399
# train 50402
# train 50405
# serve
# train 50537
# train 66449
# train 50529
# test 50532
# train 50534
# seven
# train 69463
# train 66453
# train 50617
# train 50618
# test 50620
# train 50623
# shampoo
# train 50826
# train 50827
# test 50828
# train 50830
# train 50832
# she
# train 69466
# train 50948
# train 50949
# test 50951
# train 50952
# train 50954
# shelf
# train 69467
# train 50957
# train 50958
# test 50960
# train 50964
# shopping
# train 51197
# train 51198
# train 51199
# sign language
# train 51667
# test 51658
# test 51660
# test 51662
# train 51664
# similar
# train 51738
# train 51728
# train 51729
# test 51730
# test 51731
# train 51734
# sing
# train 51810
# train 51803
# test 51804
# train 51806
# test 51807
# six
# train 69474
# train 66490
# train 51954
# train 51955
# test 51957
# train 51960
# skeleton
# train 52082
# train 52083
# test 52086
# train 52087
# train 52089
# sketch
# train 52103
# train 52104
# train 52105
# test 52107
# train 52108
# train 52110
# skill
# train 66502
# train 52143
# train 52144
# train 52147
# sleepy
# train 52344
# train 52354
# train 52345
# test 52348
# train 52349
# slip
# train 66507
# train 52430
# train 52441
# test 52442
# test 52434
# train 52435
# smell
# train 66510
# train 52603
# train 52604
# test 52606
# train 52609
# sneeze
# train 52764
# train 52765
# test 52767
# train 52770
# snob
# train 52796
# train 52797
# test 52798
# test 52799
# train 52800
# train 52802
# specific
# train 53667
# train 53668
# test 53670
# test 53671
# train 53672
# train 53675
# stamp
# train 54341
# train 54347
# train 54348
# train 54349
# train 54343
# steel
# train 54609
# train 54610
# test 54612
# test 54613
# train 54614
# train 54616
# strawberry
# train 69492
# train 55111
# train 66567
# train 66568
# test 55114
# train 55105
# test 55106
# train 55110
# subtract
# train 66577
# train 55533
# test 55534
# test 55535
# train 55536
# train 55539
# subway
# train 55553
# train 55554
# train 55555
# test 55557
# train 55560
# suffer
# train 55636
# train 55637
# train 55638
# test 55640
# train 55644
# surface
# train 56047
# train 56048
# train 56049
# test 56051
# train 56052
# train 56054
# sweep
# train 56290
# train 56281
# test 56282
# train 56284
# swing
# train 56387
# train 56388
# test 56390
# train 56394
# switzerland
# train 56423
# train 56424
# train 56425
# test 56426
# test 56427
# test 56429
# tale
# train 56779
# train 56780
# train 56782
# test 56783
# test 56784
# train 56787
# tan
# train 56874
# train 56875
# train 56876
# test 56878
# train 56881
# teeth
# train 57205
# train 57206
# test 57208
# train 57211
# terrible
# train 57492
# train 57483
# test 57484
# test 57486
# train 57487
# train 57489
# thankful
# train 57612
# train 57613
# train 57617
# test 57618
# train 57619
# they
# train 57883
# train 57874
# test 57875
# test 57876
# test 57880
# through
# train 58274
# train 58275
# train 58276
# test 58278
# train 58281
# tiptoe
# train 58575
# test 58579
# train 58580
# train 58582
# title
# train 66650
# train 58620
# train 58621
# test 58623
# train 58626
# tooth
# train 58908
# train 58909
# train 58910
# test 58911
# train 58913
# train 58915
# toothbrush
# train 58897
# train 66657
# test 58895
# train 58899
# train 58902
# total
# train 59032
# train 59033
# train 59034
# train 59037
# train 59039
# tough
# train 59079
# train 59080
# test 59082
# test 59071
# train 59072
# test 59073
# tradition
# train 66663
# test 59237
# test 59228
# train 59229
# train 59233
# trophy
# train 59723
# train 59724
# test 59725
# train 59727
# train 59729
# trouble
# train 59741
# test 66676
# test 59744
# train 59735
# test 59736
# true
# train 59791
# train 59792
# test 59793
# train 59795
# train 59797
# trust
# train 59829
# train 59830
# train 59831
# test 59833
# train 59834
# train 59836
# under
# train 60527
# train 60520
# test 60531
# train 60521
# test 60522
# verb
# train 61442
# train 61443
# test 61444
# train 61449
# wall
# train 66744
# train 62196
# train 62197
# test 62199
# train 62203
# watermelon
# train 62516
# train 62517
# train 62519
# test 62521
# train 62524
# way
# train 62577
# train 62570
# test 62571
# test 62572
# test 62575
# weird
# train 66762
# train 62818
# train 62819
# test 62821
# train 62824
# while
# train 66776
# train 63119
# train 63120
# test 63122
# train 63124
# train 63126
# wide
# train 66783
# train 63310
# train 63311
# test 63312
# train 63314
# train 63316
# willing
# train 66788
# train 63377
# train 63378
# test 63380
# train 63381
# train 63383
# wish
# train 69538
# train 63556
# test 63560
# train 63563
# wonderful
# train 66801
# train 63689
# test 63690
# test 63691
# test 63693
# train 63694
# workshop
# train 66806
# train 63821
# train 63822
# test 63824
# train 63827
# worse
# train 66811
# train 63885
# train 63886
# test 63887
# train 63889
# train 63891
# wrench
# test 64013
# train 64001
# train 64003
# a
# test 66039
# train 01610
# train 01612
# train 01615
# a lot
# test 02128
# train 02124
# train 02129
# train 02125
# test 02130
# train 02126
# train 02131
# abdomen
# test 00335
# train 00336
# train 00338
# test 00339
# train 00341
# able
# test 00376
# train 00377
# train 00381
# test 00382
# train 00384
# accountant
# test 65011
# test 00689
# train 00690
# test 00692
# train 00694
# action
# test 65015
# test 00853
# train 00854
# train 00855
# test 00856
# train 00858
# active
# test 00868
# train 00869
# train 00871
# test 00872
# train 00874
# activity
# train 65016
# train 00890
# train 00891
# test 00892
# train 00894
# address
# test 01011
# train 01018
# train 01024
# train 01012
# affect
# test 01318
# test 01319
# train 01320
# train 01321
# test 01323
# train 01327
# afraid
# test 01373
# train 01374
# train 01376
# test 01377
# train 01381
# against
# test 65033
# train 01473
# train 01474
# test 01477
# train 01479
# agenda
# train 01515
# train 01505
# test 01506
# train 01507
# ahead
# test 01598
# train 01599
# train 01602
# train 01605
# aim
# test 01642
# train 01652
# train 01653
# train 01643
# train 01646
# alcohol
# test 01831
# train 01832
# train 01836
# train 01839
# algebra
# test 01874
# train 01875
# train 01876
# test 01878
# train 01880
# all day
# train 01922
# train 01923
# train 01924
# train 01926
# train 01927
# amazing
# test 65063
# test 02273
# train 02276
# train 02269
# train 02285
# angle
# test 69210
# train 02558
# train 02559
# train 02560
# test 02561
# train 02563
# apart
# test 65081
# train 02864
# train 02865
# test 02867
# train 02870
# apostrophe
# test 65082
# test 02910
# train 02911
# train 02912
# train 02913
# train 02915
# appetite
# test 02969
# train 02970
# train 02971
# test 02973
# train 02975
# appreciate
# test 03068
# train 03069
# train 03070
# train 03073
# train 03074
# april
# test 03154
# train 03155
# train 03156
# test 03158
# train 03161
# archery
# test 03201
# train 03202
# train 03204
# test 03205
# train 03207
# around
# test 03382
# train 03389
# test 03376
# train 03377
# train 03378
# article
# test 65098
# train 03490
# train 03491
# test 03493
# assistant
# test 03756
# train 03757
# train 03758
# test 03761
# train 03763
# attend
# test 03999
# train 04000
# train 04002
# test 04003
# train 04007
# auction
# test 04099
# train 04101
# train 04102
# test 04104
# train 04106
# authority
# test 04226
# train 04227
# train 04228
# test 04230
# train 04232
# average
# test 04324
# train 04325
# train 04326
# train 04330
# train 04332
# awake
# test 65116
# train 04355
# train 04356
# test 04358
# train 04361
# b
# test 66040
# test 06120
# test 06122
# train 06124
# babysitter
# test 04531
# train 04532
# train 04533
# train 04537
# battle
# test 05368
# train 05369
# test 05372
# train 05374
# beginning
# test 05778
# train 05779
# train 05780
# train 05781
# test 05782
# train 05783
# train 05784
# belief
# test 05844
# test 05845
# train 05846
# train 05847
# train 05848
# test 05849
# train 05851
# bible
# test 06146
# test 06137
# train 06138
# train 06140
# bike
# test 06214
# train 06215
# test 06216
# train 06218
# blend
# test 06613
# train 06614
# train 06615
# test 06618
# train 06620
# bone
# test 65224
# train 07033
# test 07036
# train 07038
# bra
# test 65246
# train 07499
# train 07500
# train 07502
# brief
# test 07765
# test 07766
# train 07767
# train 07769
# train 07772
# broke
# test 07872
# test 07879
# train 07886
# test 07873
# train 07875
# bug
# test 65267
# test 08114
# train 08107
# test 08111
# bully
# test 08179
# test 08180
# train 08182
# train 08183
# test 08185
# train 08187
# button
# test 65281
# train 08468
# train 08470
# test 08472
# train 08474
# cabbage
# train 08533
# train 08535
# test 08536
# train 08538
# cabinet
# train 08543
# train 08544
# train 08545
# test 08546
# train 08547
# calculate
# test 08624
# test 08625
# train 08626
# train 08627
# train 08628
# train 08631
# train 08633
# calculator
# test 08635
# train 08636
# train 08637
# test 08639
# train 08641
# calculus
# test 08643
# train 08644
# train 08645
# test 08647
# train 08649
# camping
# test 65293
# test 08824
# train 08825
# train 08827
# train 08830
# canoe
# train 08979
# train 08980
# test 08983
# train 08985
# careless
# train 09216
# train 09220
# ceiling
# test 65320
# train 09625
# train 09626
# train 09627
# test 09628
# train 09631
# cemetery
# test 65322
# train 09712
# train 09713
# test 09715
# train 09716
# train 09717
# chapter
# test 69266
# train 10005
# train 10007
# train 10008
# train 10013
# choir
# test 10599
# test 10600
# train 10601
# train 10602
# test 10605
# train 10607
# circle
# test 10820
# train 65360
# train 10813
# train 10814
# train 10817
# come
# test 69275
# train 11884
# train 11876
# train 11877
# test 11878
# train 11882
# come here
# test 65558
# test 11862
# train 11872
# train 11863
# train 11864
# test 11865
# train 11866
# train 11867
# company
# train 12109
# train 12100
# test 12101
# train 12104
# complete
# test 12217
# train 12221
# train 12210
# test 12211
# train 12212
# concept
# test 12408
# train 65392
# train 12402
# test 12403
# concern
# test 65393
# train 12415
# train 12416
# train 12418
# train 12421
# confront
# test 12602
# test 12603
# train 12604
# train 12605
# train 12606
# train 12609
# confused
# test 65395
# test 65396
# train 12612
# train 12613
# train 12614
# train 12619
# congress
# test 12649
# train 12650
# train 12651
# train 12652
# test 12654
# train 12656
# connect
# test 65397
# train 12675
# train 12676
# test 12678
# train 12680
# conquer
# train 12704
# train 12696
# train 12700
# train 12702
# constitution
# test 12809
# train 12810
# train 12811
# train 12812
# train 12814
# train 12815
# contract
# test 12987
# train 12990
# train 12994
# court
# train 13618
# train 13619
# train 13621
# train 13623
# crab
# test 13740
# train 13732
# train 13733
# train 13734
# test 13735
# train 13737
# cross
# test 14047
# train 14057
# train 14048
# test 14049
# train 14051
# cruel
# test 14126
# train 14128
# train 14129
# test 14131
# crush
# test 69286
# train 14157
# train 14158
# train 14162
# date
# test 65442
# test 14734
# train 14728
# test 14741
# train 14729
# december
# test 15018
# train 15019
# train 15020
# test 15022
# train 15025
# decrease
# test 15110
# train 15120
# train 15111
# train 15112
# train 15116
# deduct
# test 15139
# test 15140
# train 15141
# train 15142
# train 15145
# train 15146
# defeat
# train 15185
# train 15196
# train 15199
# train 15187
# deposit
# test 15631
# test 15632
# train 15633
# train 15635
# train 15638
# depressed
# train 65466
# train 15648
# train 15649
# test 15650
# train 15652
# detach
# test 15844
# train 15845
# train 15849
# train 15850
# determine
# test 15899
# test 15900
# train 15904
# train 15907
# diabetes
# test 16002
# train 16004
# train 16005
# test 16007
# train 16009
# dime
# test 16268
# train 16269
# train 16270
# test 16272
# train 16274
# dirt
# train 16394
# train 16396
# train 16397
# test 16398
# train 16400
# disgust
# test 16640
# train 16641
# train 16642
# train 16643
# test 16644
# train 16646
# dismiss
# test 16703
# train 16704
# test 16707
# train 16709
# dizzy
# test 65501
# train 16982
# train 16984
# test 16986
# document
# test 65505
# train 17036
# train 17037
# train 17038
# test 17039
# train 17041
# train 17042
# dorm
# test 17352
# test 17353
# train 17354
# train 17355
# train 17356
# train 17359
# dormitory
# test 65522
# train 17361
# train 17362
# train 17364
# train 17365
# downstairs
# test 17456
# train 17457
# train 17458
# test 17460
# economy
# test 18370
# test 18371
# train 18372
# train 18374
# train 18377
# education
# test 65606
# train 18426
# train 18427
# train 18429
# train 18432
# effort
# test 18474
# test 18476
# train 18479
# train 18482
# eighteen
# test 65614
# test 18550
# train 18552
# train 18554
# test 18555
# train 18557
# engage
# test 65633
# test 19183
# train 19184
# train 19185
# train 19186
# engagement
# train 19192
# train 19193
# train 19194
# train 19197
# engineer
# train 19200
# train 19202
# train 19203
# test 19204
# train 19207
# envelope
# train 19393
# train 19394
# train 19395
# train 19397
# erase
# test 65641
# train 19504
# train 19505
# train 19506
# train 19509
# eternity
# test 19654
# train 19655
# train 19656
# train 19657
# train 19660
# evening
# test 19742
# train 19743
# test 19746
# train 19748
# everyday
# test 19816
# test 19820
# train 19813
# train 19818
# expand
# train 20322
# train 20313
# train 20315
# train 20318
# eye
# test 69314
# train 65665
# train 20632
# train 20633
# test 20634
# train 20636
# eyes
# test 65667
# test 20661
# train 20662
# test 20665
# train 20667
# fake
# test 20868
# train 20869
# train 65674
# test 20872
# train 20861
# train 20862
# farmer
# test 21086
# train 21087
# train 21089
# train 21092
# february
# train 21356
# train 21358
# test 21360
# train 21363
# federal
# test 21370
# train 21371
# train 21373
# train 21376
# final
# test 21820
# train 21821
# train 21822
# test 21824
# train 21826
# florida
# test 22510
# train 22511
# train 22512
# test 22514
# flute
# test 65747
# train 22610
# train 22611
# train 22612
# train 22614
# train 22615
# forbid
# test 65757
# train 22844
# test 22846
# train 22848
# forever
# test 65760
# test 22926
# train 22927
# train 22928
# test 22929
# train 22930
# fourth
# test 65774
# train 23239
# train 23240
# test 23243
# train 23246
# free
# train 65778
# train 23416
# test 23407
# train 23412
# french fries
# test 23470
# train 65780
# train 23471
# test 23473
# train 23474
# train 23475
# gamble
# test 24014
# train 24015
# train 24016
# test 24019
# train 24022
# gas
# test 65802
# test 24127
# train 24119
# train 24120
# test 24121
# train 24122
# train 24125
# gasoline
# test 24130
# test 24131
# train 24136
# train 24139
# generation
# train 24268
# train 24269
# test 24271
# train 24274
# geography
# test 24329
# train 24330
# train 24331
# train 24332
# test 24334
# train 24335
# train 24337
# german
# test 24367
# test 24368
# train 24370
# train 24372
# train 24375
# girlfriend
# test 24592
# test 24596
# train 24604
# train 24594
# test 24598
# gold
# train 24996
# train 24989
# train 24990
# train 24991
# grandma
# test 69349
# test 25422
# train 25423
# train 25427
# grass
# test 25515
# train 65850
# train 25508
# test 25509
# train 25511
# grow up
# test 25871
# train 65863
# test 25874
# train 25876
# gun
# test 26012
# train 26013
# test 26016
# train 26018
# haircut
# train 26136
# train 26139
# train 26142
# hard of hearing
# test 26591
# train 26585
# train 26586
# train 26587
# train 26593
# hippopotamus
# test 27534
# test 27535
# train 27542
# his
# test 27553
# train 27556
# test 27557
# train 27559
# honey
# train 65898
# train 65899
# test 27850
# train 27840
# train 27841
# hurricane
# test 28413
# train 28414
# train 28415
# train 28417
# train 28420
# identify
# test 65919
# train 28675
# train 28680
# test 28681
# train 28683
# include
# test 29278
# train 29279
# train 29281
# train 29284
# infection
# test 65938
# train 29562
# train 29563
# train 29564
# test 29565
# train 29566
# innocent
# test 29791
# train 29792
# train 29794
# train 29798
# insect
# test 29842
# train 29843
# train 29844
# test 29847
# train 29849
# instead
# test 65945
# train 29962
# train 29963
# test 29965
# train 29967
# institute
# test 65947
# train 29979
# train 29980
# test 29982
# train 29986
# international
# test 30217
# train 30219
# train 30223
# interrupt
# test 30285
# train 30289
# test 30278
# train 30281
# train 30283
# involve
# test 65962
# test 30522
# train 30523
# test 30526
# train 30528
# jail
# train 30873
# train 30875
# train 30876
# train 30878
# train 30879
# january
# test 30921
# train 30919
# train 30920
# test 30923
# train 30926
# joke
# test 31177
# train 31181
# train 31182
# train 31183
# train 31186
# june
# test 31346
# train 31347
# train 31348
# test 31350
# train 31353
# kangaroo
# test 65986
# train 31442
# test 31445
# karate
# test 31457
# train 31458
# train 31460
# train 31463
# kick
# test 65990
# train 31592
# train 31594
# test 31596
# train 31600
# kneel
# train 31833
# train 31834
# test 31836
# train 31838
# knock
# test 31886
# train 66001
# train 31882
# laptop
# test 32197
# train 66009
# train 32191
# test 32192
# train 32193
# train 32195
# lift
# test 69387
# test 66068
# train 33166
# train 33167
# test 33170
# train 33172
# lightning
# test 69388
# train 33246
# train 33238
# train 33240
# test 33241
# train 33243
# lip
# test 33403
# train 33404
# test 33407
# train 33410
# lipstick
# train 33423
# train 33424
# test 33426
# train 33429
# local
# test 33651
# train 33652
# train 33653
# train 33658
# manage
# test 66100
# train 34687
# train 34688
# test 34690
# train 34692
# mature
# train 35198
# train 35189
# train 35190
# test 35191
# member
# test 35574
# train 35575
# train 35576
# test 35578
# train 35581
# message
# test 35770
# train 35761
# train 35762
# train 35763
# train 35765
# metal
# train 35807
# train 35798
# test 35799
# train 35804
# microphone
# test 35923
# train 35924
# train 35925
# train 35928
# train 35931
# mix
# test 66133
# test 36460
# train 36452
# train 36462
# test 36453
# train 36454
# monthly
# test 36744
# train 36745
# train 36747
# train 36750
# motor
# test 69403
# test 37003
# train 37004
# test 37006
# train 37008
# nation
# test 37683
# train 37684
# train 37685
# train 37687
# train 37690
# network
# test 66165
# train 38043
# train 38044
# train 38045
# train 38047
# train 38048
# nickel
# test 38299
# train 38300
# train 38301
# train 38305
# nineteen
# test 66177
# test 66178
# train 38396
# train 38398
# test 38399
# train 38401
# normal
# test 66189
# train 38643
# train 38644
# test 38646
# train 38648
# november
# test 38973
# train 38974
# train 38975
# test 38977
# train 38980
# nut
# test 66220
# train 39115
# train 39116
# test 39118
# train 39120
# octopus
# test 69417
# test 66222
# train 39369
# train 39370
# train 39375
# once
# test 66227
# train 39679
# train 39680
# test 39682
# train 39686
# organize
# test 40229
# train 40230
# train 40231
# test 40234
# train 40235
# over
# test 40559
# train 40569
# train 40560
# train 40561
# train 40565
# train 40566
# owl
# test 66256
# train 40659
# train 40660
# test 40661
# train 40664
# p
# test 66054
# train 42511
# train 42513
# train 42516
# parachute
# train 41055
# train 41056
# test 41058
# train 41060
# paragraph
# test 41078
# train 41079
# train 41080
# test 41082
# train 41084
# parallel
# test 66263
# train 41094
# train 41095
# test 41097
# train 41099
# pay attention
# test 41582
# train 41580
# train 41584
# train 41585
# peace
# test 41653
# train 41654
# test 41657
# train 41659
# peanut butter
# test 66272
# train 41693
# train 41694
# test 41696
# train 41698
# perfume
# test 42039
# train 42040
# train 42041
# test 42044
# train 42045
# personality
# test 42214
# train 42215
# train 42217
# train 42220
# pet
# test 66283
# train 42308
# train 42318
# test 42309
# train 42314
# philadelphia
# train 66284
# train 66285
# train 42379
# train 42381
# physician
# test 42540
# test 42541
# train 42542
# train 42544
# test 42545
# train 42547
# piece
# test 42664
# train 42665
# train 42667
# train 42670
# pity
# test 42947
# train 42939
# train 42940
# test 42942
# train 42945
# plant
# test 43078
# train 43090
# train 43079
# test 43081
# train 43083
# plenty
# test 43254
# train 43255
# train 43257
# train 43258
# train 43261
# pneumonia
# test 43367
# train 43368
# train 43369
# test 43371
# train 43373
# politics
# test 66309
# train 43594
# train 43595
# train 43596
# train 43598
# train 43599
# position
# test 43800
# train 43801
# train 43802
# train 43807
# pound
# test 43986
# train 43996
# train 43987
# train 43988
# test 43989
# train 43994
# pour
# test 43999
# test 44007
# train 44011
# train 44000
# test 44001
# praise
# test 44097
# train 44098
# train 44100
# test 44101
# train 44103
# preach
# test 44147
# train 44148
# train 44149
# test 44151
# train 44153
# preacher
# train 44141
# train 44143
# train 44146
# prefer
# train 44221
# train 44224
# train 44227
# pressure
# test 44396
# train 44397
# train 44398
# test 44400
# train 44402
# principal
# test 66331
# test 44538
# train 44539
# train 44541
# train 44544
# priority
# test 44588
# test 44584
# train 44586
# train 44587
# professional
# test 44776
# test 44777
# train 44778
# train 44779
# train 44780
# train 44782
# train 44783
# professor
# test 44790
# train 44791
# train 44793
# test 44794
# train 44796
# promote
# test 66340
# test 44906
# train 44907
# test 44910
# prostitute
# test 45051
# train 45052
# train 45054
# train 45057
# proud
# test 45090
# train 45091
# train 45092
# test 45094
# train 45096
# quote
# test 45819
# test 45820
# train 45821
# train 45822
# test 45824
# train 45826
# receive
# test 46491
# train 46492
# train 46493
# test 46495
# train 46497
# recent
# test 66376
# test 66377
# train 46500
# train 46501
# train 46502
# test 46503
# train 46506
# reduce
# test 46759
# train 46762
# train 46752
# test 46753
# train 46754
# refer
# test 46791
# train 46792
# train 46793
# test 46795
# train 46797
# referee
# test 46775
# train 46776
# train 46779
# test 46780
# train 46783
# relate
# test 47028
# train 47029
# train 47030
# test 47032
# train 47034
# relax
# train 47059
# train 47060
# test 47063
# train 47066
# remote control
# test 66389
# train 47221
# train 47222
# train 47224
# train 47225
# rent
# test 47271
# train 47272
# train 47273
# test 47277
# train 47279
# reputation
# test 47440
# train 47441
# train 47442
# test 47444
# train 47447
# resign
# test 66394
# train 47554
# train 47555
# test 47557
# train 47561
# responsible
# test 47645
# test 47646
# train 47648
# train 47652
# ridiculous
# test 66407
# train 48073
# train 48074
# train 48077
# road
# test 48273
# train 48274
# test 48277
# train 48279
# robot
# test 48340
# train 48341
# test 48344
# train 48346
# rubber
# test 48684
# test 48685
# train 48686
# train 48688
# train 48691
# safe
# test 48995
# train 48996
# train 49006
# test 48997
# train 49002
# sauce
# test 49342
# train 49343
# train 49345
# train 49349
# sausage
# test 49358
# train 49359
# train 49362
# train 49365
# scold
# test 65577
# train 49672
# test 49673
# train 49675
# senior
# test 50372
# train 50363
# train 50364
# train 50365
# test 50367
# train 50370
# september
# test 50454
# train 50453
# train 50456
# train 50459
# train 50460
# several
# train 66458
# train 50704
# train 50705
# train 50707
# shame
# test 50813
# train 50814
# train 50815
# test 50817
# train 50819
# shave
# test 50902
# train 50904
# test 50895
# train 50896
# shoot
# test 51160
# train 51165
# train 51154
# test 51155
# train 51156
# shoulder
# test 66472
# train 51276
# test 51278
# train 51281
# silver
# test 51716
# train 51726
# train 51717
# test 51718
# train 51719
# train 51721
# simple
# test 51749
# train 51750
# train 51751
# test 51755
# train 51757
# siren
# test 66487
# test 66486
# train 51871
# train 51872
# test 51874
# train 51876
# size
# test 69475
# train 52046
# train 52047
# test 52049
# train 52051
# skate
# test 69476
# train 52072
# train 52073
# train 52076
# skin
# test 52167
# train 52158
# train 52159
# train 52160
# test 52161
# train 52163
# skunk
# test 52214
# train 52215
# train 52216
# train 52217
# train 52221
# slice
# train 66505
# train 52382
# train 52373
# train 52378
# smooth
# test 52660
# train 52662
# train 52663
# test 52665
# train 52668
# snack
# test 52686
# train 52687
# train 52688
# test 52691
# train 52694
# snowman
# test 66520
# test 66521
# train 52871
# train 52874
# train 52877
# society
# train 66526
# train 53000
# train 52992
# test 52993
# train 52997
# someone
# train 53218
# train 53220
# train 53223
# song
# test 53261
# train 53262
# train 53264
# test 53265
# train 53267
# sore throat
# test 53340
# test 53341
# train 53343
# train 53344
# train 53345
# train 53347
# south america
# test 53457
# test 53458
# train 53459
# train 53460
# train 53463
# train 53464
# spanish
# test 66541
# train 53564
# train 53565
# train 53566
# train 53570
# speak
# test 53620
# train 53621
# train 53622
# train 53623
# train 53626
# speed
# test 53736
# train 53737
# train 53738
# test 53741
# train 53744
# spell
# test 69487
# test 53771
# train 53772
# train 53773
# test 53775
# train 53778
# spoon
# train 54004
# train 54014
# train 54007
# train 54008
# spring
# test 54116
# test 54117
# train 54118
# train 54119
# test 54121
# train 54124
# standard
# test 54363
# train 54364
# train 54366
# test 54368
# train 54370
# statistics
# test 54530
# train 54531
# train 54533
# train 54536
# sticky
# test 54762
# train 54763
# train 54764
# test 54766
# train 54768
# still
# test 54787
# train 66555
# train 54780
# test 54791
# train 54781
# stretch
# test 55188
# test 55189
# train 55191
# train 55195
# surgeon
# train 56073
# test 56076
# train 56078
# sweden
# test 56271
# train 56272
# train 56273
# test 56276
# swimsuit
# test 56367
# train 56370
# train 56371
# test 56372
# train 56373
# sympathy
# train 56481
# train 56482
# test 56485
# train 56488
# take turns
# test 56762
# test 56763
# train 56764
# train 56766
# test 56767
# train 56768
# train 56769
# take up
# train 56771
# train 56772
# test 56773
# train 56775
# technology
# test 57168
# test 57169
# train 57170
# train 57172
# train 57175
# temple
# test 57321
# train 57322
# train 57323
# train 57324
# test 57327
# train 57329
# tender
# test 57368
# train 57369
# train 57371
# test 57373
# train 57374
# train 57375
# thailand
# test 57596
# test 57597
# train 57598
# train 57600
# test 57601
# train 57603
# theater
# train 57706
# train 57707
# test 57709
# train 57712
# them
# test 69503
# train 57751
# train 57752
# test 57754
# train 57756
# theme
# test 57744
# train 57745
# train 57746
# test 57748
# train 57750
# thick
# test 57890
# train 57901
# train 57892
# test 57893
# train 57896
# this
# test 69507
# train 58077
# train 66628
# train 58072
# throat
# test 58252
# train 58253
# train 58254
# test 58256
# train 58258
# tissue
# test 66649
# train 58611
# train 58612
# train 58613
# test 58614
# train 58616
# tongue
# test 66656
# train 58822
# train 58824
# test 58826
# train 58829
# tonight
# test 58834
# train 58835
# train 58836
# test 58838
# train 58840
# tornado
# test 58972
# train 58977
# test 58979
# train 58980
# train 58983
# tower
# test 59133
# train 59135
# train 59139
# tranquil
# test 59349
# train 59350
# train 59352
# test 59353
# train 59354
# transform
# test 59383
# train 59384
# train 59386
# train 59389
# tutor
# test 60057
# train 60058
# train 60059
# train 60062
# train 60064
# twin
# test 60164
# train 60155
# train 60156
# test 60159
# train 60161
# united states
# test 60730
# train 60722
# train 60723
# test 60724
# train 60728
# value
# train 61233
# train 61236
# test 61237
# visitor
# test 66732
# train 61826
# train 61827
# test 61829
# train 61831
# waiter
# train 62087
# train 62088
# train 62092
# wake up
# test 62145
# train 62143
# train 62146
# test 62148
# train 62150
# wallet
# test 66745
# test 62189
# train 62190
# train 62191
# train 62192
# train 62195
# wander
# test 62229
# train 62230
# train 62231
# test 62234
# train 62236
# wash face
# test 66748
# train 62349
# weight
# test 62790
# test 62791
# train 62792
# train 62793
# train 62796
# train 62797
# whale
# test 69530
# test 62942
# train 62933
# train 62934
# train 62936
# test 62937
# whatever
# test 66772
# train 62952
# train 62953
# train 62955
# within
# test 63598
# train 63599
# train 63600
# train 63603
# train 63604
# wonder
# test 63701
# train 66800
# train 63695
# test 63696
# train 63697
# worker
# test 66805
# train 63780
# train 63781
# test 63783
# train 63785
# worthless
# test 66812
# train 63917
# train 63918
# test 63920
# train 63922
# wrap
# test 69542
# test 63970
# train 63971
# train 63974
# test 63975
# train 63978
# accent
# test 65006
# train 00583
# train 00584
# train 00585
# train 00586
# act
# test 65014
# test 00846
# train 00847
# train 00849
# train 00851
# adapt
# test 00943
# test 00944
# train 00946
# train 00947
# train 00949
# train 00951
# adjective
# test 01064
# train 01065
# train 01066
# train 01068
# adjust
# test 01073
# test 01074
# train 01076
# train 01079
# admire
# test 65020
# test 01100
# train 01101
# train 01103
# train 01107
# admit
# test 65021
# train 01127
# train 01118
# train 01120
# train 01122
# advanced
# test 01226
# train 01227
# train 01229
# train 01231
# adverb
# test 01264
# train 01265
# train 01266
# train 01268
# agreement
# test 65037
# test 01583
# train 01584
# train 01585
# train 01586
# train 01587
# aid
# test 01621
# test 01622
# train 01624
# train 01626
# train 01627
# alligator
# test 02008
# test 02009
# train 02010
# train 02012
# train 02014
# amputate
# test 02429
# test 02430
# train 02431
# train 02434
# train 02435
# anatomy
# test 02485
# train 02487
# train 02490
# train 02492
# annoy
# train 02643
# train 02653
# train 02644
# train 02645
# anyway
# test 02851
# train 02852
# train 02854
# train 02856
# approach
# test 65088
# train 03090
# train 03092
# train 03093
# train 03096
# arizona
# test 65093
# train 03315
# train 03316
# train 03318
# assist
# test 03765
# train 03766
# train 03768
# train 03769
# train 03771
# assume
# test 03799
# train 03800
# train 03802
# train 03805
# attorney
# test 04050
# train 04051
# train 04053
# train 04055
# audiologist
# test 04129
# train 04130
# train 04132
# train 04134
# audiology
# test 04136
# train 04137
# train 04139
# train 04141
# austria
# test 04200
# test 04201
# train 04202
# train 04203
# author
# test 04218
# train 04219
# train 04221
# train 04223
# available
# test 04301
# train 04302
# train 04304
# train 04307
# award
# test 04364
# train 04369
# train 04372
# aware
# test 04375
# train 04376
# train 04378
# train 04380
# bank
# test 04971
# train 04972
# train 04974
# baptize
# test 05017
# train 05018
# train 05019
# train 05020
# train 05025
# basic
# test 65143
# train 05216
# train 05217
# train 05219
# battery
# test 65149
# train 05358
# train 05362
# berry
# test 65176
# train 05987
# train 05988
# train 05989
# train 05992
# beside
# test 06007
# train 05998
# train 05999
# train 06001
# train 06002
# between
# test 65180
# train 06081
# train 06082
# train 06083
# train 06085
# train 06087
# binoculars
# test 65185
# train 06299
# train 06300
# train 06302
# blow
# test 06787
# test 06788
# train 06789
# train 06792
# train 06794
# boast
# test 06922
# test 06923
# train 06925
# train 06928
# boil
# test 06976
# train 06968
# train 06969
# train 06972
# bookshelf
# test 07113
# train 07121
# train 07118
# bookstore
# train 07127
# train 07128
# train 07130
# train 07131
# boxing
# test 07430
# train 07431
# train 07433
# train 07435
# braid
# test 07506
# train 07509
# train 07510
# train 07515
# brain
# test 07527
# train 07528
# train 07530
# train 07532
# breakdown
# test 07613
# train 07618
# train 65253
# train 07612
# breakfast
# test 07624
# test 07625
# train 07626
# train 07628
# train 07630
# breeze
# test 07699
# train 07702
# train 07703
# train 07706
# bribe
# test 07716
# train 07718
# train 07721
# brochure
# test 07861
# train 07862
# train 07864
# train 07866
# buffalo
# test 08087
# test 08088
# train 08089
# train 08093
# train 08095
# burp
# test 08302
# train 08303
# train 08305
# train 08308
# bush
# test 08338
# test 08339
# train 08340
# train 08341
# train 08343
# train 08345
# bye
# test 08510
# train 08512
# train 08514
# train 08515
# train 08517
# camel
# test 08772
# test 08773
# train 08774
# train 08780
# candidate
# test 08889
# train 08890
# train 08891
# train 08893
# train 08894
# cannot
# test 65301
# test 08970
# train 08967
# train 08968
# train 08972
# train 08974
# captain
# test 09078
# train 09081
# train 09085
# carnival
# test 09259
# train 09260
# train 09261
# train 09262
# train 09264
# caterpillar
# test 09501
# train 09502
# train 09503
# train 09507
# cheerleader
# test 65344
# train 10250
# train 10251
# train 10252
# chemical
# test 10296
# train 10297
# train 10298
# train 10300
# train 10301
# chicago
# train 10389
# train 10391
# train 10393
# choke
# test 10609
# train 10611
# train 10612
# train 10614
# christ
# test 10679
# train 10680
# train 10682
# train 10684
# click
# test 11103
# test 11113
# train 11104
# train 11105
# closet
# test 11293
# train 11284
# train 11285
# train 11286
# train 11287
# clueless
# test 11408
# test 11409
# train 11413
# train 11414
# train 11416
# clumsy
# test 11418
# test 11419
# train 11420
# train 11422
# train 11424
# collect
# test 11686
# test 11687
# train 11689
# train 11693
# comma
# test 11930
# train 11931
# train 11933
# train 11935
# comment
# test 65382
# test 11971
# train 11972
# train 11973
# train 11978
# commit
# test 11994
# test 11995
# train 11997
# train 12000
# committee
# test 65383
# train 12005
# train 12006
# train 12008
# train 12010
# common sense
# test 12023
# train 12024
# train 12025
# train 12027
# train 12028
# compete
# test 12158
# test 12159
# train 12161
# train 12164
# concentrate
# test 12391
# train 12392
# train 12394
# congratulations
# test 12636
# train 12637
# train 12638
# train 12641
# consider
# test 12755
# train 12758
# train 12759
# train 12761
# construct
# test 12819
# test 12820
# train 12823
# train 12824
# train 12826
# consume
# test 65398
# test 12863
# train 12855
# train 12860
# contest
# test 12942
# train 12943
# train 12945
# train 12947
# conversation
# test 13087
# train 13091
# train 13093
# train 13094
# train 13095
# convert
# test 13106
# test 13109
# train 13111
# train 13114
# cooperate
# test 13223
# train 13224
# train 13228
# counsel
# test 65412
# train 13499
# train 13500
# train 13501
# train 13503
# counselor
# train 13508
# train 13509
# train 13510
# train 13512
# crave
# test 65420
# test 13819
# train 13820
# train 13822
# train 13824
# create
# test 13877
# train 13878
# train 13880
# train 13881
# crocodile
# test 65425
# test 14011
# train 14013
# train 14015
# crown
# test 14102
# train 14103
# train 14105
# train 14107
# cuba
# test 14202
# test 14203
# train 14204
# curtain
# train 14393
# train 14396
# customer
# test 14432
# train 14433
# train 14437
# train 14438
# d
# test 66042
# test 15996
# train 15998
# train 16000
# damage
# test 14602
# train 14604
# train 14606
# train 14608
# dancer
# test 65436
# train 14635
# train 14636
# train 14638
# danger
# test 14645
# train 14646
# train 14647
# train 14648
# train 14650
# dangerous
# test 65438
# test 65437
# train 14652
# train 14653
# train 14656
# train 14657
# dawn
# test 14773
# train 14774
# train 14777
# train 14778
# death
# test 14952
# train 14953
# train 14954
# train 14955
# train 14957
# debate
# test 14961
# train 14964
# train 14966
# train 14968
# debt
# test 14978
# test 14979
# train 14981
# train 14984
# deliver
# test 15401
# train 15402
# train 15405
# train 15406
# democrat
# test 15448
# train 15449
# train 15450
# train 15453
# descend
# test 15704
# train 15695
# train 15701
# train 15702
# design
# test 65468
# train 15750
# train 15751
# train 15753
# train 15755
# detective
# train 15876
# train 15878
# train 15880
# devil
# test 65474
# train 15957
# train 15958
# dice
# test 65478
# test 16117
# train 16110
# train 16114
# difficult
# test 16212
# train 16213
# train 16216
# train 16220
# dining room
# test 16314
# train 16315
# train 16316
# train 16317
# train 16319
# discipline
# test 16502
# test 16503
# train 16504
# train 16506
# train 16511
# discount
# test 16541
# train 16542
# train 16544
# train 16546
# disgusted
# test 65492
# train 16635
# train 16636
# train 16639
# disturb
# test 16872
# test 16873
# train 16877
# train 16878
# train 16880
# division
# test 16958
# train 16950
# train 16951
# train 16955
# done
# test 69300
# test 17206
# train 17209
# train 17212
# train 17214
# drag
# train 17521
# train 17512
# train 17514
# dragon
# test 17529
# test 17530
# train 17532
# drama
# test 17557
# test 17559
# train 17560
# train 17562
# train 17564
# drug
# test 17877
# train 17878
# train 17889
# train 17883
# due
# test 65552
# train 17959
# train 17960
# train 17961
# train 17964
# train 17965
# dull
# test 17968
# test 17976
# train 17979
# train 17969
# train 17974
# train 17975
# dusk
# test 18037
# test 18038
# train 18040
# train 18042
# train 18043
# dvd
# test 18069
# test 18070
# train 18071
# train 18073
# dye
# test 18091
# train 18092
# train 18095
# train 18096
# e
# test 66043
# train 18533
# train 18535
# train 18537
# either
# test 18649
# train 65617
# train 18644
# electricity
# test 18727
# test 18728
# train 18729
# train 18732
# train 18734
# elementary
# test 18756
# train 18757
# train 18759
# train 18761
# else
# test 18856
# train 18858
# train 18861
# emergency
# test 18942
# train 18944
# train 18946
# train 18949
# engine
# test 19212
# train 19213
# train 19214
# train 19215
# train 19217
# enormous
# test 19297
# test 19298
# train 19299
# train 19300
# train 19303
# eraser
# test 19512
# train 19513
# train 19514
# train 19515
# train 19517
# every monday
# test 19852
# train 19853
# train 19855
# train 19856
# train 19857
# every tuesday
# test 19930
# train 19931
# train 19933
# train 19934
# train 19935
# everything
# test 65649
# train 19911
# train 19912
# train 19915
# except
# test 20109
# train 20110
# train 20111
# train 20113
# train 20115
# exhibit
# test 20256
# test 20257
# train 20260
# train 20262
# explode
# test 65662
# train 20456
# train 20457
# train 20459
# express
# test 65664
# train 20510
# train 20511
# train 20513
# f
# test 66044
# train 21568
# train 21570
# train 21572
# fairy
# test 20836
# test 20837
# train 20838
# train 20839
# familiar
# test 20967
# train 20969
# train 20973
# festival
# test 21524
# train 21525
# train 21527
# train 21529
# finance
# test 21838
# train 21839
# train 21841
# train 21843
# fingerspell
# test 21925
# train 21923
# train 21928
# fire
# test 22015
# train 22019
# train 22010
# firefighter
# test 65726
# test 21993
# train 21994
# train 21999
# train 22003
# five
# test 69326
# test 65734
# train 22191
# train 22192
# train 22194
# flatter
# test 22357
# train 22358
# train 22359
# train 22362
# fool
# test 65754
# test 22780
# train 22772
# train 22783
# train 22774
# forgive
# test 22974
# train 22975
# train 22976
# train 22978
# train 22980
# former
# test 23038
# train 65764
# train 23030
# train 23031
# train 23035
# freeway
# test 23434
# train 23425
# train 23427
# train 23428
# from now on
# test 23646
# test 23647
# train 23648
# train 23650
# train 23652
# g
# test 66045
# train 24523
# train 24525
# train 24527
# gang
# test 24043
# train 24044
# train 24046
# train 24048
# gay
# test 65804
# train 24203
# train 24194
# train 24195
# geometry
# test 24343
# test 24344
# train 24345
# train 24347
# train 24349
# get up
# test 65814
# test 24498
# train 24499
# train 24500
# train 24502
# train 24503
# gift
# test 24547
# train 24548
# train 24553
# train 24555
# grab
# test 65841
# train 25279
# train 25280
# train 25282
# graduation
# test 25350
# test 25351
# train 25353
# train 25354
# train 25356
# grateful
# test 25522
# train 25524
# train 25526
# train 25527
# train 25528
# grey
# train 25714
# train 25721
# gymnastics
# test 26062
# test 26063
# train 26067
# train 26069
# h
# test 27357
# train 66046
# train 27355
# train 27359
# hang up
# test 26472
# train 26463
# train 26464
# hanukkah
# test 26483
# train 26484
# train 26485
# train 26487
# heap
# test 65883
# test 26931
# train 26932
# train 26935
# train 26937
# heart attack
# test 27018
# train 27019
# train 27020
# train 27022
# train 27023
# hill
# test 27486
# train 27487
# train 27492
# holy
# test 27744
# train 27754
# train 27745
# train 27746
# train 27748
# hop
# test 27940
# train 27942
# train 27943
# train 27945
# host
# test 28056
# train 28067
# train 28069
# train 28057
# train 28058
# hot dog
# test 28085
# train 28096
# train 28082
# train 28087
# train 28091
# human
# test 28288
# train 28291
# train 28292
# train 28296
# i
# test 66047
# train 28789
# train 28791
# train 28794
# ill
# train 28820
# train 28821
# train 28824
# train 28827
# illegal
# test 28813
# train 28814
# train 28815
# train 28817
# train 28818
# impact
# test 65925
# test 29007
# train 29008
# train 29010
# train 29011
# individual
# test 65933
# train 29462
# train 29463
# train 29468
# inspect
# test 29897
# test 29898
# train 29900
# train 29901
# train 29903
# inspire
# test 65943
# test 29919
# train 29920
# train 29921
# train 29924
# intersection
# test 30297
# train 30298
# train 30301
# train 30304
# ireland
# test 65963
# train 30584
# train 30585
# train 30587
# iron
# test 65964
# test 30603
# train 30595
# train 30596
# j
# test 66048
# train 31100
# train 31102
# train 31104
# jewelry
# test 65978
# train 31077
# train 31078
# train 31079
# train 31080
# train 31082
# journey
# test 31218
# train 31220
# train 31221
# train 31223
# joy
# test 31232
# test 31233
# train 31236
# train 31237
# train 31239
# july
# test 31300
# train 31306
# train 31301
# train 31303
# k
# test 66049
# train 31583
# train 31585
# train 31587
# kid
# test 65991
# test 31621
# train 31612
# train 31613
# train 31614
# kindergarten
# test 31687
# test 31688
# train 31689
# train 31691
# train 31693
# lady
# test 32046
# test 32047
# train 32049
# train 32050
# train 32052
# lamp
# train 32097
# train 32094
# last week
# test 66011
# train 32276
# train 32277
# train 32278
# train 32280
# laundry
# test 32421
# train 32422
# train 32424
# train 32427
# leader
# test 32530
# train 32520
# train 32521
# train 32522
# train 32523
# league
# test 66022
# train 32562
# train 32563
# leak
# test 32575
# train 32579
# train 32569
# train 32570
# train 32571
# legal
# test 32754
# train 32755
# train 32757
# train 32759
# let
# test 32911
# train 32915
# train 32916
# train 32918
# liability
# test 33000
# train 33001
# train 33002
# train 33003
# train 33005
# librarian
# test 33042
# train 33043
# train 33044
# train 33047
# license
# test 33063
# train 33066
# train 33069
# little bit
# train 33518
# train 33519
# train 33521
# loan
# test 33616
# train 33609
# train 33612
# look at
# test 33851
# train 33857
# look for
# train 33881
# train 33882
# train 33884
# lord
# test 33980
# train 33981
# train 33983
# train 33986
# m
# test 66051
# train 35897
# train 35899
# train 35901
# meaning
# test 35306
# test 35307
# melody
# test 35555
# train 35556
# train 35557
# train 35558
# train 35560
# melt
# test 35567
# train 35568
# train 35570
# train 35572
# mention
# train 66115
# train 66116
# train 35676
# microscope
# test 35932
# train 35933
# train 35935
# train 35937
# midnight
# test 35986
# train 35988
# train 35990
# train 35992
# military
# test 36037
# train 36038
# train 36040
# mine
# test 36139
# test 36140
# train 36142
# train 36146
# mistake
# test 36399
# train 36400
# train 36402
# train 36404
# mock
# train 36489
# train 36490
# train 36492
# moose
# test 36801
# test 36802
# train 36804
# train 36808
# mosquito
# train 36910
# train 36901
# train 36903
# train 36906
# motivate
# test 66148
# test 36969
# train 36970
# train 36971
# train 36973
# train 36975
# murder
# test 37305
# train 37306
# train 37308
# train 37310
# n
# test 66052
# train 38265
# train 38267
# train 38269
# narrow
# test 37647
# train 37648
# train 37650
# train 37652
# necessary
# test 37828
# train 37829
# train 37831
# train 37833
# negotiate
# test 37940
# train 37932
# train 37933
# new york
# test 38212
# train 38211
# train 38214
# train 38216
# nine
# test 66173
# test 38373
# train 38374
# train 38376
# train 38378
# northwest
# test 38701
# train 38702
# train 38704
# train 38706
# not yet
# test 38944
# train 38945
# train 38949
# train 38946
# notice
# test 66193
# test 38871
# train 38872
# train 38873
# train 38875
# train 38878
# numerous
# test 39067
# train 39070
# train 39071
# train 39072
# train 39073
# nun
# test 39076
# train 39077
# train 39080
# train 39082
# o
# test 66053
# train 39553
# train 39555
# train 39557
# objective
# test 39198
# train 39199
# train 39201
# train 39203
# obsess
# test 66221
# test 39253
# train 39254
# train 39255
# train 39256
# train 39257
# train 39258
# obtain
# test 39285
# test 39286
# train 39287
# train 39289
# train 39291
# occur
# test 39334
# train 39335
# train 39337
# odor
# test 39387
# train 39388
# train 39389
# train 39390
# train 39392
# olympics
# test 39647
# train 39649
# train 39652
# or
# train 40239
# train 40240
# train 40242
# oral
# test 40104
# train 66245
# train 40097
# train 40102
# our
# test 40342
# train 40343
# train 40345
# train 40347
# overcome
# test 40528
# train 40529
# train 40531
# train 40532
# train 40533
# pack
# test 66258
# test 40722
# train 40723
# train 40726
# train 40728
# painter
# test 40828
# train 40829
# train 40830
# train 40831
# train 40833
# part
# test 41262
# train 41263
# train 41265
# train 41267
# pause
# test 41559
# train 41563
# train 41553
# train 41554
# train 41555
# peaceful
# test 41644
# test 41645
# train 41646
# train 41647
# train 41648
# train 41649
# train 41650
# pear
# test 66273
# train 41705
# train 41708
# peel
# test 41774
# train 41775
# train 41777
# train 41780
# penalty
# test 41811
# train 41812
# train 41814
# train 41816
# pennsylvania
# test 66277
# train 41896
# train 41897
# train 41899
# train 41900
# penny
# test 41902
# train 41905
# train 41907
# permit
# train 42148
# train 42137
# train 42138
# train 42142
# phrase
# test 42501
# test 42502
# train 42503
# train 42504
# train 42505
# train 42507
# pickle
# test 42605
# train 42607
# train 42608
# train 42609
# pilot
# test 42761
# train 42762
# train 42764
# train 42767
# player
# test 66300
# train 43147
# train 43149
# train 43151
# polar bear
# test 43507
# test 43508
# train 43510
# train 43511
# train 43513
# policeman
# test 43536
# train 43537
# train 43538
# train 43539
# train 43540
# poop
# test 66311
# test 43671
# train 43672
# train 43674
# train 43677
# post
# test 43873
# test 43885
# potential
# test 43945
# train 43946
# train 43948
# train 43949
# train 43950
# poverty
# test 44019
# train 44020
# train 44023
# train 44024
# precious
# test 44175
# train 66321
# train 44167
# train 44168
# train 44172
# precipitation
# test 44176
# test 44177
# train 44178
# train 44179
# train 44180
# train 44182
# precise
# test 44184
# train 44185
# train 44186
# train 44188
# preschool
# test 44299
# train 44301
# train 44303
# pride
# test 44485
# train 44486
# train 44487
# train 44488
# train 44490
# prince
# test 44524
# train 44526
# train 44529
# princess
# test 44532
# train 44534
# train 44537
# principle
# test 44549
# train 44550
# train 44551
# train 44552
# train 44555
# process
# test 44715
# train 44716
# train 44719
# train 44721
# profit
# test 44811
# train 44812
# train 44814
# train 44817
# progress
# test 44843
# train 44844
# train 44847
# train 44849
# propaganda
# test 44958
# train 44962
# proper
# test 44970
# train 44971
# train 44973
# train 44975
# psychologist
# train 45164
# train 45166
# train 45168
# public
# test 45193
# train 45194
# train 45196
# train 45198
# train 45199
# publish
# test 45218
# test 45219
# train 45220
# train 45221
# train 45223
# train 45224
# purchase
# test 45410
# test 45411
# train 45413
# train 45416
# pure
# test 45419
# test 45420
# train 45423
# train 45425
# pursue
# test 45468
# train 45469
# train 45471
# train 45473
# put off
# test 45525
# train 45526
# train 45529
# train 45530
# train 45532
# q
# test 66055
# train 45597
# train 45599
# train 45601
# quality
# test 66360
# train 45637
# train 45638
# train 45639
# train 45640
# quarrel
# test 45652
# train 45655
# train 45656
# train 45658
# quarter
# test 45663
# train 45673
# train 45664
# train 45665
# train 45669
# r
# test 66056
# train 47983
# train 47985
# train 47987
# rage
# test 45928
# train 45929
# train 45932
# train 45936
# rather
# test 46165
# train 46166
# train 46170
# train 46173
# real
# test 46314
# train 46315
# train 46317
# train 46319
# recliner
# test 46574
# test 46575
# train 46578
# train 46580
# recommend
# test 46606
# train 46607
# train 46609
# train 46611
# recover
# test 46658
# train 46659
# train 46660
# train 46661
# train 46663
# train 46665
# regular
# test 66383
# test 46927
# train 46928
# train 46930
# release
# test 47075
# test 47076
# train 47077
# train 47081
# train 47083
# relief
# test 66385
# train 47093
# train 47094
# train 47095
# train 47096
# train 47097
# rely
# test 47136
# train 47137
# train 47139
# train 47140
# train 47142
# reply
# test 47342
# train 47343
# train 47345
# train 47347
# rescue
# test 47479
# train 47480
# train 47482
# train 47484
# resist
# test 66395
# train 47569
# train 47572
# restroom
# test 47722
# train 47724
# train 47727
# retreat
# test 47803
# train 47804
# train 47806
# train 47809
# roar
# test 48298
# train 48299
# train 48301
# train 48303
# robber
# test 48306
# train 48307
# train 48308
# train 48311
# train 48313
# roommate
# test 66417
# train 48522
# train 48523
# train 48525
# train 48526
# rose
# test 48566
# test 48567
# train 48569
# train 48570
# train 48573
# ruin
# test 48731
# train 48732
# train 48734
# train 48737
# s
# test 66057
# train 51426
# train 51428
# train 51430
# salary
# test 49089
# train 49090
# train 49092
# train 49093
# train 49094
# saw
# test 49411
# train 49421
# train 49410
# scan
# test 49459
# train 49460
# train 49465
# scream
# test 49779
# train 49783
# train 49786
# sculpture
# test 49885
# train 49886
# train 49887
# train 49888
# train 49889
# train 49890
# sea
# test 69459
# test 49898
# train 49899
# train 49900
# train 49902
# seldom
# train 50198
# train 50199
# train 50201
# sequence
# train 50466
# train 50467
# train 50469
# train 50471
# train 50472
# settle
# test 66452
# train 50582
# train 50584
# train 50587
# shout
# test 51300
# train 51303
# train 51306
# shovel
# train 51313
# train 51315
# train 51317
# sin
# test 51826
# train 51827
# train 51829
# train 51831
# singer
# test 51796
# train 51798
# train 51800
# train 51801
# sixteen
# test 66494
# test 51979
# train 51981
# train 51982
# train 51984
# train 51986
# ski
# train 52122
# train 52128
# skip
# test 66504
# train 52181
# train 52185
# train 52188
# smoking
# test 52651
# train 52656
# sofa
# test 53037
# train 53038
# train 53039
# train 53041
# soldier
# test 53119
# test 53120
# train 53123
# train 53126
# solve
# test 53178
# train 53179
# train 53180
# train 53182
# someday
# test 53196
# test 53198
# train 53199
# train 53200
# train 53203
# something
# test 53230
# train 53231
# train 53233
# train 53235
# somewhere
# test 53252
# train 53253
# train 53255
# train 53257
# soul
# test 53401
# train 53404
# train 53405
# train 53406
# train 53409
# spill
# test 53850
# train 53851
# train 53854
# train 53855
# spit
# test 53921
# train 53922
# train 53924
# train 53926
# spread
# test 54090
# train 54092
# train 54093
# train 54095
# sprint
# test 54138
# test 54139
# train 54140
# train 54143
# train 54144
# train 54146
# squeeze
# test 54189
# train 54190
# train 54191
# train 54195
# stadium
# test 54248
# test 54249
# train 54250
# train 54251
# train 54252
# train 54254
# stepfather
# train 54672
# train 54667
# sting
# test 54805
# train 54807
# train 54810
# stir
# test 54837
# train 54832
# train 54833
# train 54834
# stitch
# test 54840
# train 54841
# train 54843
# train 54845
# stuck
# test 55323
# train 55324
# train 55326
# train 55328
# sue
# train 55627
# train 55628
# train 55631
# train 55632
# sunshine
# test 55866
# train 55867
# train 55868
# train 55869
# train 55871
# superman
# test 55910
# test 55911
# train 55913
# train 55917
# surrender
# test 56114
# train 56115
# train 56117
# train 56119
# suspend
# test 56175
# train 56176
# train 56178
# train 56180
# swimming
# test 56354
# test 56355
# train 56356
# train 56357
# train 56359
# train 56360
# t
# test 66058
# train 58323
# train 58325
# train 58327
# talent
# test 56792
# train 56793
# train 56795
# train 56798
# telescope
# test 57251
# test 57252
# train 57253
# train 57255
# train 57257
# tempt
# test 57349
# train 57351
# train 57354
# ten
# test 57391
# test 57392
# train 57393
# train 57395
# train 57397
# tend
# test 57378
# train 57380
# train 57385
# testify
# train 57552
# train 57543
# train 57545
# train 57546
# train 57548
# texas
# test 57567
# train 57568
# train 57570
# text
# test 57584
# test 66595
# train 66596
# train 57579
# train 57580
# train 57582
# than
# test 66597
# train 57605
# train 57606
# train 57610
# therefore
# test 57819
# train 57820
# train 57822
# thrill
# test 66634
# train 58243
# train 58244
# train 58245
# train 58247
# tobacco
# train 58664
# train 58665
# train 58667
# train 58669
# toilet paper
# test 58745
# train 58746
# train 58748
# train 58750
# tolerate
# test 58769
# train 58770
# train 58772
# train 58774
# torture
# test 59001
# train 59002
# train 59003
# train 59005
# towel
# test 59122
# train 59123
# train 59124
# train 59127
# train 59129
# trip
# test 59672
# test 59673
# train 59666
# train 59669
# train 59670
# truth
# test 59839
# test 59840
# train 59842
# train 59843
# train 59846
# turn
# test 66684
# train 59991
# train 59992
# train 59996
# tv
# test 69520
# train 60075
# u
# test 66059
# train 60358
# train 60360
# train 60362
# unique
# test 60702
# train 60703
# train 60704
# train 60705
# train 60708
# train 60709
# upstairs
# test 60967
# train 60968
# train 60970
# v
# test 66060
# train 61561
# train 61563
# train 61565
# vacant
# test 61135
# train 61136
# train 61138
# train 61140
# vague
# test 61188
# train 61189
# train 61191
# train 61193
# valley
# test 61221
# train 61222
# train 61224
# train 61226
# vampire
# test 66718
# test 61246
# train 61247
# train 61249
# train 61251
# very
# test 69523
# test 66722
# train 61509
# train 61510
# train 61512
# train 61515
# vice president
# test 61588
# train 61590
# train 61592
# train 61595
# viewpoint
# test 61697
# train 61699
# train 61700
# train 61701
# train 61702
# visualize
# test 66733
# train 61846
# train 61848
# train 61850
# train 61851
# vlog
# test 66734
# test 61869
# train 61870
# train 61874
# volleyball
# test 61953
# train 61947
# train 61948
# train 61950
# train 61952
# w
# test 66061
# train 63274
# train 63276
# train 63278
# washington
# train 62393
# train 62394
# train 62395
# train 62396
# train 62398
# waterfall
# test 62488
# train 62489
# train 62490
# train 62492
# train 62493
# weigh
# train 62782
# train 62783
# train 62785
# wheelchair
# test 63044
# train 63046
# train 63047
# train 63050
# whistle
# train 63186
# train 63188
# train 63190

# %%
import mediapipe as mp
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import os
import shutil
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import glob
import cv2
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
np.random.seed(42)



# Create a Holistic object to detect pose, face, and hands keypoints
mp_holistic = mp.solutions.holistic

# Drawing utilities
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, model):
    if image is None:
        raise ValueError(f"Failed to load image: {image}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

def draw_styled_landmarks(image, results):

    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

def adjust_landmarks(arr,center):

    # Reshape the array to have shape (n, 3)
    arr_reshaped = arr.reshape(-1, 3)

    # Repeat the center array to have shape (n, 3)
    center_repeated = np.tile(center, (len(arr_reshaped), 1))

    # Subtract the center array from the arr array
    arr_adjusted = arr_reshaped - center_repeated

    # Reshape arr_adjusted back to shape (n*3,)
    arr_adjusted = arr_adjusted.reshape(-1)
    return(arr_adjusted)

def extract_keypoints(results):

    pose = np.array([[res.x, res.y, res.z] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    nose=pose[:3]
    lh_wrist=lh[:3]
    rh_wrist=rh[:3]
    pose_adjusted = adjust_landmarks(pose,nose)
    lh_adjusted = adjust_landmarks(lh,lh_wrist)
    rh_adjusted = adjust_landmarks(rh,rh_wrist)
    return pose_adjusted, lh_adjusted, rh_adjusted

selected_words = os.listdir('kaggle/working/Dataset/frames/Train')

def make_keypoint_arrays(path,split):

    os.makedirs('kaggle/working/Dataset/npy_arrays',exist_ok = True)
    os.makedirs(f'kaggle/working/Dataset/npy_arrays/{split}',exist_ok = True)
    working_path = f'kaggle/working/Dataset/npy_arrays/{split}'
    words_folder = os.path.join(path, split)
    selected_words1=[]
    for words1 in selected_words:
        npy_fold = os.listdir(os.path.join(working_path))
        if words1 not in npy_fold:
            selected_words1.append(words1)
    i=1
    # Loop through all the subfolders in the folder
    for word in tqdm(selected_words1):
        npy_fold = os.listdir(os.path.join(working_path))
        if word not in npy_fold:
            video_files = os.listdir(os.path.join(words_folder, word))
              # Loop through the video files
            for video_file in video_files:
                    # Open the video file
                video = sorted(os.listdir(os.path.join(words_folder, word, video_file)))

                # Initialize the list of keypoints for this video
                pose_keypoints, lh_keypoints, rh_keypoints = [], [], []
                with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
                  # Loop through the video frames
                  for frame in video:
                      # Perform any necessary preprocessing on the frame (e.g., resizing, normalization)
                    frame = os.path.join(words_folder, word, video_file,frame)
                    frame = cv2.imread(frame)
        #                 frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

                      # Normalize pixel values to the range [0, 1]
                    # Make detections
                    image, results = mediapipe_detection(frame, holistic)

                    # Extract keypoints
                    pose, lh, rh = extract_keypoints(results)
                    # Add the keypoints to the list for this video
                    pose_keypoints.append(pose)
                    lh_keypoints.append(lh)
                    rh_keypoints.append(rh)
                    # Save the keypoints for this video to a numpy array
                    pose_directory = os.path.join(working_path, word,'pose_keypoints')
                    lh_directory = os.path.join(working_path, word,'lh_keypoints')
                    rh_directory = os.path.join(working_path, word,'rh_keypoints')

                    if not os.path.exists(pose_directory):
                        os.makedirs(pose_directory)

                    if not os.path.exists(lh_directory):
                        os.makedirs(lh_directory)

                    if not os.path.exists(rh_directory):
                        os.makedirs(rh_directory)

                    pose_path = os.path.join(pose_directory, video_file)
                    np.save(pose_path, pose_keypoints)

                    lh_path = os.path.join(lh_directory, video_file)
                    np.save(lh_path, lh_keypoints)

                    rh_path = os.path.join(rh_directory, video_file)
                    np.save(rh_path, rh_keypoints)

make_keypoint_arrays('kaggle/working/Dataset/frames','Train/')
make_keypoint_arrays('kaggle/working/Dataset/frames','Test/')

words= np.array(os.listdir('kaggle/working/Dataset/frames/Train'))
print(words)

label_map = {label:num for num, label in enumerate(words)}
print(label_map)

def preprocess_data(data_path,split,f_avg):

    # Initialize the lists of sequences and labels
    sequences = []
    labels = []

    # Iterate over the words
    for word in tqdm(words):
        word_path = os.path.join(data_path, split, word)
        word_id = os.path.basename(word_path).zfill(4)

        lh_keypoints_folder = os.path.join(word_path, "lh_keypoints")
        rh_keypoints_folder = os.path.join(word_path, "rh_keypoints")
        pose_keypoints_folder = os.path.join(word_path, "pose_keypoints")

        # Iterate through the sequences (numpy arrays) contained in the lh_keypoints folder
        for sequence in os.listdir(lh_keypoints_folder):
            # Load the left hand array
            res_lh = np.load(os.path.join(lh_keypoints_folder, sequence))

            # Determine how many frames to select
            num_frames = min(res_lh.shape[0], f_avg)
            res_lh = res_lh[:num_frames, :]
            while num_frames < f_avg:
                res_lh = np.concatenate((res_lh, np.expand_dims(res_lh[-1, :], axis=0)), axis=0)
                num_frames += 1

            # Load the right hand array
            res_rh = np.load(os.path.join(rh_keypoints_folder, sequence))

            # Determine how many frames to select
            num_frames = min(res_rh.shape[0], f_avg)
            res_rh = res_rh[:num_frames, :]
            while num_frames < f_avg:
                res_rh = np.concatenate((res_rh, np.expand_dims(res_rh[-1, :], axis=0)), axis=0)
                num_frames += 1

            # Load the pose array
            res_pose = np.load(os.path.join(pose_keypoints_folder, sequence))

            # Determine how many frames to select
            num_frames = min(res_pose.shape[0], f_avg)
            res_pose = res_pose[:num_frames, :]
            while num_frames < f_avg:
                res_pose = np.concatenate((res_pose, np.expand_dims(res_pose[-1, :], axis=0)), axis=0)
                num_frames += 1

            # Append the subsequence to the list of sequences
            sequences.append(np.concatenate((res_pose, res_lh, res_rh), axis=1))
            # Append the label to the list of labels
            labels.append(label_map[word])

    # Convert the lists of sequences and labels to numpy arrays
    X = np.array(sequences)
    y = to_categorical(labels).astype(int)

    return X, y

#train and validation splits
data_path = 'kaggle/working/Dataset/npy_arrays'

X_train,y_train=preprocess_data(data_path,'Train/',48)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)

#test split
X_test,y_test=preprocess_data(data_path,'Test',48)

print(X_test.shape)
print(y_test.shape)

# Define the Bidirectional LSTM model with Attention
model = tf.keras.Sequential([
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(words), activation='softmax')
])

# Compile the model

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# Set up early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Metric to monitor for early stopping
    mode='min',  # Set mode to 'min' for minimizing the metric
    patience=5,  # Number of epochs with no improvement before stopping
    restore_best_weights=True,  # Restore the best model weights
    verbose=1
)

model_training_history = model.fit(X_train, y_train, batch_size=32, validation_data=(X_val,y_val), validation_batch_size=32, epochs=100)

# Evaluate the model on train data
model_evaluation_history = model.evaluate(X_train, y_train)

# Evaluate the model on test data
model_evaluation_history = model.evaluate(X_test, y_test)

def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):


    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# Visualize the training and validation loss metrices.
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# Visualize the training and validation accuracy metrices.
plot_metric(model_training_history, 'categorical_accuracy', 'val_categorical_accuracy', 'Total Accuracy vs Total Validation Accuracy')

#Predicted sign
res = model.predict(X_test)
words[np.argmax(res[1])]

#Real sign
words[np.argmax(y_test[1])]

# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'ASL_Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

os.makedirs('kaggle/working/Model',exist_ok=True)
# Save your Model.
model.save(f'kaggle/working/Model/{model_file_name}')

yhat = model.predict(X_test)

def get_key_by_value(dictionary, value):
    for key, val in dictionary.items():
        if val == value:
            return key
    return None

ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

y = []
for v in ytrue:
    y.append(get_key_by_value(label_map, v))
print(y)



ypred = []
for v in yhat:
    ypred.append(get_key_by_value(label_map, v))
print(ypred)



from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming y and ypred are your target labels and predicted labels, respectively

# Select the first 20 classes
y_subset = y[:200]
ypred_subset = ypred[:200]

# Get unique class labels
class_labels = np.unique(y_subset)

# Compute confusion matrix
cm = confusion_matrix(y_subset, ypred_subset, labels=class_labels)

# Create a DataFrame from the confusion matrix
df_cm = pd.DataFrame(cm, index=class_labels, columns=class_labels)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.3)  # for label size
sns.heatmap(df_cm, cmap="Blues", annot=True, fmt="d", annot_kws={"size": 12})
plt.title("Confusion Matrix - First 20 Classes")
plt.show()
# Out:
#   0%|                                                   | 0/188 [00:00<?, ?it/s]INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 100%|█████████████████████████████████████████| 188/188 [38:11<00:00, 12.19s/it]
#   9%|███▊                                      | 17/188 [01:10<11:49,  4.15s/it]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 154
#     151                     np.save(rh_path, rh_keypoints)
#     153 make_keypoint_arrays('kaggle/working/Dataset/frames','Train/')
# --> 154 make_keypoint_arrays('kaggle/working/Dataset/frames','Test/')
#     156 words= np.array(os.listdir('kaggle/working/Dataset/frames/Train'))
#     157 print(words)
#
# Cell In[10], line 104, in make_keypoint_arrays(path, split)
#     102 npy_fold = os.listdir(os.path.join(working_path))
#     103 if word not in npy_fold:
# --> 104     video_files = os.listdir(os.path.join(words_folder, word))
#     105       # Loop through the video files
#     106     for video_file in video_files:
#     107             # Open the video file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kaggle/working/Dataset/frames/Test/different'

# %%
import os
import shutil
ld=os.listdir('kaggle/working/Dataset/frames/Test')
ld_=os.listdir('kaggle/working/Dataset/frames/Train')
#for elem in ld[150:]:
    #shutil.rmtree(os.path.join(f'/kaggle/working/Dataset/frames/Test/',elem))
    #shutil.rmtree(os.path.join(f'/kaggle/working/Dataset/frames/Test/',elem))
for elem in ld_:
    if elem not in ld:
        shutil.rmtree(os.path.join(f'kaggle/working/Dataset/frames/Train/',elem))
print(len(ld_))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 import shutil
# ----> 3 ld=os.listdir('/kaggle/working/Dataset/frames/Test')
#       4 ld_=os.listdir('/kaggle/working/Dataset/frames/Train')
#       5 #for elem in ld[150:]:
#       6     #shutil.rmtree(os.path.join(f'/kaggle/working/Dataset/frames/Test/',elem))
#       7     #shutil.rmtree(os.path.join(f'/kaggle/working/Dataset/frames/Test/',elem))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/Dataset/frames/Test'

# %%
tr=os.listdir('kaggle/working/Dataset/frames/Train/')
te=os.listdir('kaggle/working/Dataset/frames/Test/')
print(len(tr),len(te))
for elem in tr:
    if elem not in te:
        print(elem)
